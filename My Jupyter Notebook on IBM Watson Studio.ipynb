# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Mucteba Sinan Yildirim__

# %% [markdown]
# I am a management student. I want to go Germany to take master degree in the field of Finance.

# %% [markdown]
# _I am interested in data science because I notice that data science is the most valuable and sexiest science in our century._

# %% [markdown]
# ### I try to find calculation of 56*78.

# %%
x= 56*78
print(x)
# Out:
# 4368

# %% [markdown]
# 1) Data Science
# 2) Marketing
# 3) Finance
# 4) Operation Management
# ***
